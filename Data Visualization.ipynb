# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Mir Abdul Malique\Downloads\HV_Python\weather.csv")

# %%
df.head()
# Out:
#          date      city  AWND  PRCP  SNOW  TAVG  TMAX  TMIN
# 0  2020-01-01   Atlanta   7.2   0.0   0.0  45.0  57.0  36.0
# 1  2020-01-01    Boston  15.4   0.0   0.0  39.0  43.0  36.0
# 2  2020-01-01   Chicago  11.9   0.0   0.0  28.0  42.0  21.0
# 3  2020-01-01  Honolulu   6.3   0.0   NaN  76.0  81.0  68.0
# 4  2020-01-01   Houston   6.5   0.1   0.0  52.0  60.0  47.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3751 entries, 0 to 3750
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3751 non-null   object
#  1   city    3751 non-null   object
#  2   AWND    3751 non-null   float64
#  3   PRCP    3751 non-null   float64
#  4   SNOW    2046 non-null   float64
#  5   TAVG    3748 non-null   float64
#  6   TMAX    3751 non-null   float64
#  7   TMIN    3751 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 234.6+ KB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3751 entries, 0 to 3750
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 3751 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 29.4 KB

# %%
#want to see data of city atlanta
atlanta=df.query("city=='Atlanta'")[['TAVG', 'TMAX', 'TMIN']]

# %%
df['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3751 entries, 0 to 3750
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 3751 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 29.4 KB

# %%
atlanta
# Out:
#       TAVG  TMAX  TMIN
# 0     45.0  57.0  36.0
# 11    47.0  50.0  46.0
# 22    56.0  63.0  50.0
# 33    56.0  59.0  37.0
# 44    41.0  55.0  32.0
# ...    ...   ...   ...
# 3696  41.0  58.0  29.0
# 3707  46.0  61.0  33.0
# 3718  52.0  66.0  39.0
# 3729  51.0  54.0  44.0
# 3740  49.0  56.0  44.0
#
# [341 rows x 3 columns]

# %%
atlanta['TMAX'].plot(kind='box')
# Out:
# <Axes: >

# %%
atlanta['TMIN'].plot(kind='box')
# Out:
# <Axes: >

# %%
atlanta['TAVG'].plot(kind='box')
# Out:
# <Axes: >

# %%
sns.boxplot(y='TMAX',data=df)
# Out:
# <Axes: ylabel='TMAX'>

# %%
box=df.iloc[:,5:]
for i in box:
    sns.boxplot(y=i,data=df)
    plt.show()

# %%
sns.histplot(x='TMAX',data=df)
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TMAX', ylabel='Count'>

# %%
df['TMAX'].skew()
# Out:
# -0.3134846266593979

# %%
df['TMAX'].kurt()
# Out:
# -0.2377484829414418

# %%
sns.histplot(x='AWND',data=df)
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='AWND', ylabel='Count'>

# %%
weather_num=df.select_dtypes(np.number)

# %%
weather_num
# Out:
#       AWND  PRCP  SNOW  TAVG  TMAX  TMIN
# 0      7.2  0.00   0.0  45.0  57.0  36.0
# 1     15.4  0.00   0.0  39.0  43.0  36.0
# 2     11.9  0.00   0.0  28.0  42.0  21.0
# 3      6.3  0.00   NaN  76.0  81.0  68.0
# 4      6.5  0.10   0.0  52.0  60.0  47.0
# ...    ...   ...   ...   ...   ...   ...
# 3746  16.6  0.00   NaN  76.0  81.0  73.0
# 3747  10.7  0.53   0.0  46.0  50.0  38.0
# 3748   5.1  0.00   NaN  51.0  60.0  41.0
# 3749   9.8  0.03   NaN  54.0  60.0  47.0
# 3750  12.1  0.35   0.0  48.0  50.0  46.0
#
# [3751 rows x 6 columns]

# %%
for i in weather_num:
    sns.histplot(x=i,data=weather_num)
    plt.show()
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
weather_num.skew()
# Out:
# AWND     0.918303
# PRCP     7.426607
# SNOW    22.639643
# TAVG    -0.269541
# TMAX    -0.313485
# TMIN    -0.275736
# dtype: float64

# %%
weather_num.kurt()
# Out:
# AWND      0.981925
# PRCP     92.377215
# SNOW    654.867996
# TAVG     -0.344350
# TMAX     -0.237748
# TMIN     -0.499617
# dtype: float64

# %%
sns.displot(x='TMAX',data=weather_num, kind='kde',color='b',label='TMAX')
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(x='TMAX',data=weather_num,color='b', fill=True ,label='TMAX')
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TMAX', ylabel='Density'>

# %%
df1=pd.read_csv(r"C:\Users\Mir Abdul Malique\Downloads\HV_Python\age_sal.csv")

# %%
df1.head()
# Out:
#    Age  Annual Salary  Weekly hours                    Education
# 0   72       160000.0          40.0  Bachelor's degree or higher
# 1   72       100000.0          50.0  Bachelor's degree or higher
# 2   31       120000.0          40.0  Bachelor's degree or higher
# 3   28        45000.0          40.0  Bachelor's degree or higher
# 4   54        85000.0          40.0  Bachelor's degree or higher

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            500 non-null    int64
#  1   Annual Salary  500 non-null    float64
#  2   Weekly hours   500 non-null    float64
#  3   Education      500 non-null    object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
sns.scatterplot(x='Age',y='Annual Salary',data=df1)
# Out:
# <Axes: xlabel='Age', ylabel='Annual Salary'>

# %%
sns.relplot(x='Age',y='Annual Salary',data=df1)

# %%
sns.scatterplot(x='Age',y='Annual Salary',data=df1,hue='Education')
# Out:
# <Axes: xlabel='Age', ylabel='Annual Salary'>

# %%
data=pd.read_csv(r"C:\Users\Mir Abdul Malique\Downloads\HV_Python\movie_scores.csv")

# %%
data.head()
# Out:
#                           MovieTitle  Tomatometer  AudienceScore
# 0                 The Shape of Water           91             73
# 1                      Black Panther           97             79
# 2                            Dunkirk           92             81
# 3                        The Martian           91             91
# 4  The Hobbit: An Unexpected Journey           64             83

# %%
data.shape
# Out:
# (5, 3)

# %%
data['MovieTitle'].unique()
# Out:
# array(['The Shape of Water', 'Black Panther', 'Dunkirk', 'The Martian',
#        'The Hobbit: An Unexpected Journey'], dtype=object)

# %%
data.plot(x='MovieTitle',y='Tomatometer',kind='barh')
# Out:
# <Axes: ylabel='MovieTitle'>

# %%
data.plot(x='MovieTitle',y='AudienceScore',kind='barh')
# Out:
# <Axes: ylabel='MovieTitle'>

# %%
data.plot(x='MovieTitle',y=['Tomatometer','AudienceScore'],kind='barh')
# Out:
# <Axes: ylabel='MovieTitle'>

# %%
sns.catplot(data,x='Tomatometer',y='MovieTitle',kind='bar')

# %%
df1=pd.read_csv(r"C:\Users\Mir Abdul Malique\Downloads\HV_Python\flights.csv")

# %%
df1.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df1.shape
# Out:
# (144, 3)

# %%
df1.plot(x='year',y='passengers')
# Out:
# <Axes: xlabel='year'>

# %%
plt.plot(df1['passengers'])

# %%
sns.lineplot(x='year',y='passengers',data=df1)
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(x='year',y='passengers',hue='month',data=df1)
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='passengers'>

# %%
help(sns.lineplot)
# Out:
# Help on function lineplot in module seaborn.relational:
#
# lineplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, seed=None, orient='x', sort=True, err_style='band', err_kws=None, legend='auto', ci='deprecated', ax=None, **kwargs)
#     Draw a line plot with possibility of several semantic groupings.
#
#     The relationship between `x` and `y` can be shown for different subsets
#     of the data using the `hue`, `size`, and `style` parameters. These
#     parameters control what visual semantics are used to identify the different
#     subsets. It is possible to show up to three dimensions independently by
#     using all three semantic types, but this style of plot can be hard to
#     interpret and is often ineffective. Using redundant semantics (i.e. both
# ...

# %%
sns.lineplot(df1.query("month=='Jan'"),x='year',y='passengers')
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='passengers'>

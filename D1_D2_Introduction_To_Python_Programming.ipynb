# %% [markdown]
# ## Week-1

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#intro)
#
# 2. [Appilcation of Python](#appli)
#
# 3. [Componet of the python  program](#token)
#     - [Keywords](#key)
#     - [Identifiers](#id)
#     - Literals (Data Types)
#     - Operators
#
# 4. [Data Types (Numeric and Sequential data types)](#data)
#     - [Numeric Data](#num_data)
#         - Integer
#         - Float
#         - Complex
#
#     - [Sequential Data](#seq_data)
#         - String
#         - List
#         - Tuple
#         - Set
#         - Dictionary
#
# 5. [Operators and Type of operators](#op)

# %% [markdown]
# ---
#
# # What is programming language?
#
# A programming language is an intermediate language between human and computer, that is used to communicate with computers.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---
#
# # Where can you use Programming (Python) to interact with a computer or carry out various tasks?...
# ---
#
# ## [IDLE](https://en.wikipedia.org/wiki/IDLE) : Integrated Development and Learning Environment.
# - **"IDLE"** typically refers to the Integrated Development and Learning Environment for Python. IDLE is a popular and user-friendly integrated development environment (IDE) for Python programming.
#
# - Example: VSCode, Pycharm, Atom, Sypder, **Jupyter Notebook** and etc.
#
# ---

# %% [markdown]
# ### Jupyter notebook?
# ---
# Jupyter is an IDE typically used to develop data analysis and data science solutions. Jupyter, in its early days was called IPython(Hence the extension - ipynb) but it was changed to Jupyter to reflect the inclusion of support for other programming languages. It actually provides support for 40+ languages. The name Jupyter is an amalgamation of the major programming languages it supports - `JUlia PYTon E R`
#
# ---

# %% [markdown]
# ---
# ### Reason to use Jupyter
# There are two major reasons we're using Jupyter over other IDEs
# - Jupyter has the provision to include rich media(images, hyperlinks, plots, graphs, audio, text formatting etc..)
# - Debugging in Jupyter is much more easier compared to other IDEs/Editors
#
# ---

# %% [markdown]
# ---
#
# # Few keyboard shortcuts:
# - `Esc` + `M`: Convert a coding cell into markdown
# - `Esc` + `Y`: Convert a markdown cell into the code mode
# - `Shift` + `Enter`: To execute/run the current cell
# - `Esc` + `A`: To add a new cell atop the current cell
# - `Esc` + `B`: To add a new cell below the current cell
# - `Esc` + `DD`: To delete the current cell
#
# ---

# %% [markdown]
# ---
# # Headings
# Headings are important in documents as they lead the reader in on what is the topic being dealt. Jupyter makes use of Hashes(#) to indicate Headings.
#
# Syntax:
#     #s text
#
# ---

# %% [markdown]
# # Heading Style 1
# ## Heading Style 2
# ### H3
# #### H4
# ##### H5
# ###### H6

# %% [markdown]
# # Text Highlighting
# Text in jupyter can be highlighted by enclosing it in backticks(`)

# %% [markdown]
# # Horizontal Rule
# Line breaks are used to demark different sections in the document. Include three consecutive hyphens in a line of their own to give a horizontal rule

# %% [markdown]
# line11
# line12
#
# ---
#
# line21
#
# ---
#
# line31
# line32
# line33

# %% [markdown]
# # Text emphasis
# We can emphasize a text in jupyter by either putting it in bold or italics
#
# **Bold statement** is bolded and *italics* is italicized
#
# ***bold and italic***

# %% [markdown]
# # Lists
# Lists are collections which help us stay organised. There are two kinds of lists:
# - Ordered list
# - Unordered list

# %% [markdown]
# ### Unordered lists
# Unordered lists are collections of items where the ordering isn't important. We can put either `+`, `-` or `*` before an item to indicate that it belongs to an unordered list

# %% [markdown]
# - item1
# - item2
# + item3
# + item4
# * item5
# * item6

# %% [markdown]
# ### Ordered lists
# Ordered lists are collections of items where the ordering is important. We have to give a number followed by a full-stop to indicate that it's an ordered list

# %% [markdown]
# 1. item1
# 2. item2
# 3. item3
# 4. item4
# 5. 5th one

# %% [markdown]
# # Hypertext
# Hypertext is a text on internet which when clicked upon redirects us to a new web page
#
# Syntax:
#
#     [Text](url *tooltip)

# %% [markdown]
# Click [this](https://www.wikipedia.org/ "Go to Wiki") to go to the Wikipedia homepage

# %% [markdown]
# [This](https://www.google.co.in/) takes me to google

# %% [markdown]
# ### Image
#
# ![Data Science](https://miro.medium.com/max/2560/1*4oRB4tZrc4OLUeoc-p4wKQ.png)

# %% [markdown]
# ![Dog](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](https://www.python.org/static/img/python-logo@2x.png)
#
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically-typed and garbage-collected. It supports multiple programming paradigms, including structured, object-oriented and functional programming.
#
# The official Website can be found [here](https://www.python.org/).

# %% [markdown]
# ## Introduction <a class="anchor" id="intro"></a>
# Python is a powerful and versatile programming language. It's free to use and was created by Guido van Rossum in 1991 at the University of Amsterdam.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Appilcation of Python <a class="anchor" id="appli"></a>
# - **`Web Development`**: Python is used for building websites and web applications with frameworks like Django and Flask.
#
# - **`Data Science and Machine Learning`**: Python is the primary language for data analysis, machine learning, and artificial intelligence with libraries like NumPy and scikit-learn.
#
# - **`Scientific Computing`**: Python is favored by scientists for data analysis, simulation, and visualization, utilizing libraries like SciPy and Matplotlib.
#
# - **`Automation and Scripting`**: Python is a go-to choice for automating tasks and creating scripts for various applications, from file manipulation to system administration.

# %% [markdown]
# # Component of the Python Program (Token)  <a class="anchor" id="token"></a>
#
#
# ---
# A "token" is the smallest unit of a Python program. Tokens are the building blocks of Python code and are used to represent various elements in your code.
#
# ----
#
# - **Keywords**
# - **Identifiers**
# - **Data Types (Literals)**
# - **Operators**
# - **Punctuation Symbols**: These symbols are used for structuring the code, such as colons (`:`), commas (`,`), parentheses (`()`), square brackets (`[]`), and curly braces (`{}`).
#
# - **Comments**: Comments are text in your code that is meant for human readers and is ignored by the Python interpreter. Python supports both single-line comments using `#` and multi-line comments using triple-quotes (`'''` or `"""`).
#
# -  **Whitespace**: Whitespace tokens include spaces, tabs, and newlines, which are used for code formatting but are not considered tokens in themselves.

# %% [markdown]
# ### 1. Keywords <a class="anchor" id="key"></a>
# ![image.png](attachment:image.png)

# %%
import keyword
k_words = keyword.kwlist
print(k_words)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("Total number of keywords : ",len(k_words))
# Out:
# Total number of keywords :  35

# %% [markdown]
# In Python, we've got **35 special words** called **`"keywords"`** These keywords are a bit like the **ABCs** of the Python language, and it's important to remember that they care about capital letters (**case sensitive**), so be mindful of that! 😊

# %% [markdown]
# ## 2. Identifiers <a class="anchor" id="id"></a>
# ![image.png](attachment:image.png)
# - Think of identifiers in Python as **`nametags`** for different things like **classes, functions, or variables**.
# - They're like **containers that hold values**, making it easy to tell one thing apart from another. So, just like you put labels on your toy boxes, Python uses identifiers to keep things organized! 😊

# %%
name = "Feynman"
x= 100
data = [24,27,12]
x_1 = 453

# %% [markdown]
# - `name`, `x`, `data`, and `x_1` are like **nametags (identifiers)** in Python.
# - They act as **containers**, holding different things. For instance, `name` holds the name **`"Feynman"`**, `x` holds the number **`100`**, `data` holds a **list of numbers**, and `x_1` holds the number **453**.
# These identifiers help us keep track of what's inside each container, just like labels on jars help us know what's inside them.

# %% [markdown]
# ## 3. Data Types (Literals) <a class="anchor" id="data"></a>
# ---
# In the realm of Python, we primarily engage with two categories of data types:
# 1. Numeric Data
# 2. Sequential Data
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## Numeric Data <a class="anchor" id="num_data"></a>
# ---
# Numeric data in Python is like a trio of friends:
#
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **`Integer`**: Think of them as the whole, no-nonsense numbers - no decimals, just plain and simple. <a class = "anchor" id = 'int'></a>
#
# Eg:
# ```python
# 1,4,-445,8,0
# ```
# ---
#
# 2. **`Float`**: These are the cool kids with decimal points - they add a little twist to the party! <a class = "anchor" id = 'flts'></a>
#
# Eg:
# ```python
# 1.2,4.0,-445.7,0.0
#
# ```
# ---
# 3. [**`Complex`**](https://pythonguides.com/complex-numbers-in-python/#:~:text=secondsVolume%200%25-,Creating%20Complex%20Numbers%20in%20Python,Output%3A,-2.The%20second): And then we have the complex ones, like mathematical adventurers with both real and imaginary parts - they add a touch of mystery to the mix.
#
# Eg:
#
# ```python
#
# 3+ 4j, -5 +1j
#
# ```
#
# ---
#
# Python's numeric data types are your trusty sidekicks for all sorts of number-crunching fun! 🚀🔢😄

# %% [markdown]
# ### Boolean Data: The `Yes` or `No` of Programming
#
# - Picture this: In the world of programming, there's a special data type called **Boolean**, and it's a lot like a **magic switch**.
#
# - This switch has only two settings: **"Yes"** (which we call **True**) and **"No"** (we call that **False**). It's like a superhero with two secret identities!
#
# ---
#
# Imagine you're playing a game, and someone asks, **"Are you ready?"** If you are, you're **"True"** to go, but if not, you're **"False"** to the adventure.
#
# ---
#
# So, while numbers in **Python are the heroes of mathematics, Booleans are the champions of decisions**, making programming as exciting as choosing your next adventure! 🎮🦸‍♀️🚀
#
# ```python
# # Are you ready for an adventure?
# ready = True
# ```

# %%
a = 45   # integer
b = 4.5  # float
print(a)
print(b)
# Out:
# 45
# 4.5

# %%
# type() is  used to  know  the  data type 
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %% [markdown]
# # Task
# ### Implement a basic calculator that can perform addition, subtraction, multiplication, and division based on user input.

# %%
# with integers
n1 = 5
n2 = 3

add = n1 + n2

sub = n1 - n2

prod = n1 * n2 

div = n1/n2

int_div  = n1 // n2  # here '//' is used for integer division, that returns only  integer

print("Addition : ",add)
print('Substraction :', sub)
print('Multipication : ',prod)
print('Divsion : ',div)
print('Integer divison :',  int_div)
# Out:
# Addition :  8
# Substraction : 2
# Multipication :  15
# Divsion :  1.6666666666666667
# Integer divison : 1

# %% [markdown]
# ---
# ## Practice Questions
# ---
#
# ### Q1. Perform all the above mathematical operations with floats.

# %%
x = 4
y = 3
SUM = x + y
print(SUM)
# Out:
# 7

# %% [markdown]
# ###  Q2. Write a program that can calculate the `Simple Interest` of given values of P, R and T.

# %% [markdown]
# ### Q3. Write a program that swap two given numbers.
#
# ```python
# # input
# x = 7
# y = 3
#
# # outputs
# x = 3
# y = 7
#
# ```

# %% [markdown]
# # Sequential Data <a class="anchor" id="seq_data"></a>
#
# Sequential data refers to the **ordered collection of items**, which can include objects, characters, numbers, and so on.
#
# ---
#
# ![image.png](attachment:image.png)
#
# ---
# There are the following data in Python:
# 1. String
# 2. List
# 3. Tuple
# 4. Set
# 5. Dictionaries
# ---
#
# ## String <a class = 'anchor' id = 'str'></a>
# ---
#
# - In Python, a string is a sequence of characters enclosed within quotes. Python treats **single (‘ ’)** or **double quotes (“  ”)** as equal.
# -  A string can also be enclosed into the triple quotes (''' some text...'''). That can be used for multiple lines of strings.
# - A string is immutable (cannot be modified).
# syntax:
# ```python
# text1 = "hello python"
# text2 = 'hello python'
# ```
#
# Here text1 and text2 are variables and both are string data.

# %%
text1 = "Hello Python"
text2 = 'Hello python'
text3 = '''This is also string and,
triple qoutes can use for multiple lines of text'''

# here print() is used to display the value
print(text1)
print(text2)
print(text3)
# Out:
# Hello Python
# Hello python
# This is also string and,
# triple qoutes can use for multiple lines of text

# %% [markdown]
# - **Indexing**: To access an individual item from a string (list/tuple) is called indexing.
# - Indexing in a string can be done in two ways **forward** and **backward** indexing.
# ---
# ![image.png](attachment:image.png)
#
# ---
#
# **Note:** Only an integer is used for indexing, we cannot use float value for indexing.

# %%
# indexing
text1[5]
# Out:
# ' '

# %%
text1[6] # forward indexing
# Out:
# 'P'

# %%
text1[-4]  # backward indexing
# Out:
# 't'

# %% [markdown]
# **Slicing** to get a sub-string from the given string (list/ tuple).
#
# ```python
# text[start : end+1  : steps]
# ```

# %%
text1[2:12:2]
# Out:
# 'loPto'

# %%
text1[3:]
# Out:
# 'lo Python'

# %%
text1[:3]
# Out:
# 'Hel'

# %%
text1[:]  # to get all the characters from the string
# Out:
# 'Hello Python'

# %% [markdown]
# ### Transforming Data Types
# ---
# We can also change the data type of the given data and it is called **type casting**.
#
# ---
#
# ![image.png](attachment:image.png)

# %%
num = 46
print(num)
# Out:
# 46

# %%
st = str(num)  # typecasted into a string
st
# Out:
# '46'

# %% [markdown]
# ---
# ### **f-string**
# It is a special type of string and we can put some value in the string.
#
# ---

# %%
name = "Allen Turing"
text1 = "The  father of  computer science is {name}"
text2 = f"The  father of  computer science is {name}."

print(text1)
print(text2)
# Out:
# The  father of  computer science is {name}
# The  father of  computer science is Allen Turing.

# %%
n1 = 5
n2 = 6

text = f"The value of n1 is {n1}"
print(text)
# Out:
# The value of n1 is 5

# %% [markdown]
# ### String Operation
# ---
# A string can only have two mathematical operations.
# - Concatenation of strings
# - multiplications with integer

# %%
# Concatenation (adding two or more strings)
s1 = "hello"
s2 = "programmer"
print(s1 + s2)
# Out:
# helloprogrammer

# %%
print(s1 + ' ' + s2)  # ' ' (space) is also string
# Out:
# hello programmer

# %%
# string can  only multiple with integers
s1* 3
# Out:
# 'hellohellohello'

# %%
s1 * 3.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s1 * 3.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ### Methods and functions of the string
# ---
# There are some methods and functions of the string :
# - `len()`  It is used to get the length of the string.
# - `replace()` used to replace a string character.
# - `upper()` and `lower()`
# - `islower()` and `isupper()`
# - `split()` It is used to split the string into a list of characters separated by space (default).
#
# ## How do we find out what a method does?
#
# There are so many in-built methods and functions available for the string. To know more about  methods we can use one of the  following techniques:
# - .
# ```python
# help(str)
# dir(str)
# ```
# - Google search

# %%
s = "Hello,  let's learn python"

# len
len(s)  # number of characters in the string
# Out:
# 26

# %%
s.upper()
# Out:
# "HELLO,  LET'S LEARN PYTHON"

# %%
s.lower()
# Out:
# "hello,  let's learn python"

# %%
'H'.isupper() # gives  true or  false value
# Out:
# True

# %%
'H'.islower()
# Out:
# False

# %%
x = "Hello Python"
x
# Out:
# 'Hello Python'

# %%
x[3] = "L"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x[3] = "L"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ---
# ## List <a class = 'anchor' id = 'lst'></a>
#
# - List is an ordered collection of the items (data) enclosed in the square bracket ([]).
# -  List is mutable (can be modified) and It can also be indexed like a string.
# ---

# %%
lst = [2,3,4,5.5,3 +5j,"Name"]
print(lst)
# Out:
# [2, 3, 4, 5.5, (3+5j), 'Name']

# %%
type(lst)
# Out:
# list

# %%
lst = [2,4,6.5,'ML','Python']
print(lst)
# Out:
# [2, 4, 6.5, 'ML', 'Python']

# %%
# type() is used to know data types in the python
type(lst)
# Out:
# list

# %% [markdown]
# ---
# #### Indexing
# ---
# - Indexing in the list is the same as string, we can index a list in both ways **forward** and **backward**.
# -  List is mutable.

# %%
lst
# Out:
# [2, 3, 4, 5.5, (3+5j), 'Name']

# %%
# indexing ---> forward indx
lst[3]
# Out:
# 5.5

# %%
# backward indexing
lst[-1]
# Out:
# 'Name'

# %%
lst[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lst[7]
#
# IndexError: list index out of range

# %%
# silcing
lst
# Out:
# [2, 3, 4, 5.5, (3+5j), 'Name']

# %%
lst[:] # all the element
# Out:
# [2, 3, 4, 5.5, (3+5j), 'Name']

# %%
lst[:3]  # we want elements before 3
# Out:
# [2, 3, 4]

# %%
lst[3:]  # everything after 3 index
# Out:
# [5.5, (3+5j), 'Name']

# %%
lst[2:6]
# Out:
# [4, 5.5, (3+5j), 'Name']

# %%
# 
lst[2:6:2]
# Out:
# [4, (3+5j)]

# %% [markdown]
# #### properties of the list
# 1. List mutable

# %%
lst
# Out:
# [2, 3, 4, 5.5, (3+5j), 'Name']

# %%
lst[2]
# Out:
# 4

# %%
# lsit is mutable
lst[2] = 220

# %%
lst
# Out:
# [2, 3, 220, 5.5, (3+5j), 'Name']

# %%
lst[4]
# Out:
# 'Python'

# %%
# list is mutable
print('Before : ', lst)

lst[2] = 6689

print('After : ',lst)
# Out:
# Before :  [2, 4, 6.5, 'ML', 'Python']
# After :  [2, 4, 6689, 'ML', 'Python']

# %% [markdown]
# ### Methods and functions of the List
# ---
# There are some methods and functions of the list:
# - `append()` It is used to add a new item to the list.
# - `extend()` It is used to combine the two lists.
# - `pop()` It removes the last item from the list.
# ---
# Apart from the, we have many functions in the list like ```python del[], remove(), sort(), reverse(), insert(), count(), clear()``` etc.
# To more about the list's function and method
# `help(list)` or `dir(list)`

# %%
l = []
print(l)
# Out:
# []

# %%
# length of the sequential data
len(l)
# Out:
# 0

# %%
# append
l.append("Newton")

# %%
l
# Out:
# ['Newton']

# %%
l.append("Bohr")

# %%
l
# Out:
# ['Newton', 'Bohr']

# %%
"Hello".upper()
# Out:
# 'HELLO'

# %%
s = "hello"

s.upper()
# Out:
# 'HELLO'

# %%
s
# Out:
# 'hello'

# %%
l = []   # empty list
print(l)
# Out:
# []

# %%
len(l)  # length of the list
# Out:
# 0

# %%
# appned
l.append(2)  # add new 2 in  the  list

# %%
l.append(4)
l.append('ML')
print(l)
# Out:
# [2, 4, 'ML']

# %%
# append
# extend
lst = [1,2,3,4]
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.append(5)

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
# we want to add more than 1 item
lst.extend([6,7,8])

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.append([6,7,8])

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, [6, 7, 8]]

# %%
# pop()
lst.pop()
# Out:
# [6, 7, 8]

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.pop(2)
# Out:
# 3

# %%
lst
# Out:
# [1, 2, 4, 5, 6, 7, 8]

# %%
# reverse
lst.reverse()

# %%
lst
# Out:
# [8, 7, 6, 5, 4, 2, 1]

# %%
del lst[2]

# %%
lst
# Out:
# [8, 7, 5, 4, 2, 1]

# %% [markdown]
# #### List  operations
# List support following types of  mathematical operations:
# - Concatenation of list
# - multiplications with integer

# %%
# Concatenation of list
mylist1 = [2,3,4]
mylist2 = [9,7,1]

mylist1 + mylist2
# Out:
# [2, 3, 4, 9, 7, 1]

# %%
mylist1 - mylist2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 mylist1 - mylist2
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
# multipication  with a interger
mylist1 * 4
# Out:
# [2, 3, 4, 2, 3, 4, 2, 3, 4, 2, 3, 4]

# %%
mylist1 * 2.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 mylist1 * 2.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ## Tuples <a class = 'anchor' id = 'tpl'></a>
# ---
# - Tuple is like a list, and it is an ordered collection of items enclosed in the "(...)".
# - But the only difference, a tuple is immutable hence values can't be changed in place.

# %%
tple = 2,2,3,4,5,5,5,6
tple
# Out:
# (2, 2, 3, 4, 5, 5, 5, 6)

# %%
# typecasting into the list
list(tple)
# Out:
# [2, 2, 3, 4, 5, 5, 5, 6]

# %%
# set()
set(tple)
# Out:
# {2, 3, 4, 5, 6}

# %%
str(tple)
# Out:
# '(2, 2, 3, 4, 5, 5, 5, 6)'

# %%
# creating a tuple
tpl1 = (2,3,5,8.2)
tpl2 = 2,9,'ML',3.1   # we can also defined this way

print(tpl1)
print(tpl2)
# Out:
# (2, 3, 5, 8.2)
# (2, 9, 'ML', 3.1)

# %%
x = 2,3,4
x
# Out:
# (2, 3, 4)

# %%
type(x)
# Out:
# tuple

# %%
x = ()
x
# Out:
# ()

# %%
type(x)
# Out:
# tuple

# %%
x = 2,
x
# Out:
# (2,)

# %%
type(x)
# Out:
# tuple

# %% [markdown]
# #### Indexing and slicing same as string and list.

# %%
# forward indexing
tpl1[0]   # first element
# Out:
# 2

# %%
tpl1
# Out:
# (2, 3, 5, 8.2)

# %%
# forwarding indexing
tpl1[1]
# Out:
# 3

# %%
# backward indexing
tpl1[-1]
# Out:
# 8.2

# %%
# slcing
tpl1[:]
# Out:
# (2, 3, 5, 8.2)

# %%
tpl1[:2]
# Out:
# (2, 3)

# %%
tpl1[2:]
# Out:
# (5, 8.2)

# %%
# tuple is immutable
tpl1[2] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 # tuple is immutable
# ----> 2 tpl1[2] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
x = "hello"
x[2] = "L"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 x = "hello"
# ----> 2 x[2] = "L"
#
# TypeError: 'str' object does not support item assignment

# %%
# tuple is immutable, it's means we cannot modify
tpl1[2] = 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 # tuple is immutable, it's means we cannot modify
# ----> 2 tpl1[2] = 8
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Set <a class = 'anchor' id = 'st'></a>
# ---
# -  Set is an **unordered** collection of items, in which there is **no duplicates** are allowed.
# -  Indexing and slicing are not allowed in the set because the set is unordered.

# %%
s = {1,2,3,-3,5,1,2,2,2}
print(s)
# Out:
# {1, 2, 3, 5, -3}

# %%
s = {}
print(s)
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s = set()
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %%
l = []
set(l)
# Out:
# set()

# %%
s = set()
s
# Out:
# set()

# %%
# adding one item
s.add(5)

# %%
s
# Out:
# {5}

# %%
s.add(12)
s
# Out:
# {5, 12}

# %%
# 
s.add(5.0)
s
# Out:
# {5, 12}

# %%
# you want to add more than 1 items
s.update({5,2,3})

# %%
s
# Out:
# {2, 3, 5, 12}

# %%
# remove
s.remove(-5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 2
#       1 # remove
# ----> 2 s.remove(-5)
#
# KeyError: -5

# %%
s
# Out:
# {2, 3, 5, 12}

# %%
# clear
s.clear()

# %%
s
# Out:
# set()

# %%
# creating empty set
st  = set()
print(st)
# Out:
# set()

# %% [markdown]
# ### Methods and functions of the Set
# ----
# There are some methods and functions of the set:
# - `union()`   take the union of the two sets
# - `intersection()`  take  the intersection  of the  two sets
# - `add()`   add an item in the  set
# - `update()` add multiple items in  the set
# - `remove()`  removing a element
# - `clear()`   deleting all the  items

# %%
s1 = {1,2,3,4,5,5,5,6}
s2 = {5,4,10,20,30,40}
print(s1)
print(s2)
# Out:
# {1, 2, 3, 4, 5, 6}
# {4, 5, 20, 40, 10, 30}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 10, 20, 30, 40}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
# union()
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 10, 20, 30, 40}

# %%
# intersection
s1.intersection(s2)
# Out:
# {4, 5}

# %%
# add()
s1.add(100)
s1
# Out:
# {1, 2, 3, 4, 5, 6, 100}

# %%
# clear() --> this function wipe all the data inside the set
s1.clear()
print(s1)   # empty set
# Out:
# set()

# %% [markdown]
# ### Q4. Write a program to find the sum of all unique items in a given set.
# ```python
# st = {1,2,1,5,8,3,2,1,2}
#
# # Expected Output
# # The sum of the unique values :  19
#
# ```

# %%
st = {1,2,1,5,8,3,2,1,2}

# %%
st
# Out:
# {1, 2, 3, 5, 8}

# %%
sum(st)
# Out:
# 19

# %% [markdown]
# ## Dictionary (Mapping) <a class = 'anchor' id = 'dict'></a>
# ---
# - A dictionary is a collection of **key-value** pairs and it maps keys to values.
# - Where each element is accessed (or indexed) by a unique key.
# - Dictionary is **mutable** (can be modified if needed).
# - In a dictionary, no duplicate keys are allowed.
# Syntax:
#
# ```python
# my_dict = {'key1': 'value1','key2': 'value2','key3': 'value3.......keyn: valuen'}
# ```

# %%
d = {"Write": "Likhna", "Read":"Pdana"}
print(d)
# Out:
# {'Write': 'Likhna', 'Read': 'Pdana'}

# %%
type(d)
# Out:
# dict

# %%
# len of the dictionary
len(d)
# Out:
# 2

# %%
# index --> to access indivaul item is called indexing
# in L[2]
d["Write"]
# Out:
# 'Likhna'

# %%
d["Read"]
# Out:
# 'Pdana'

# %%
# dictionary is mutable--> we can modify the dict
d["Read"] = 344213

# %%
d
# Out:
# {'Write': 'Likhna', 'Read': 344213}

# %%
# adding new itmems in the dictionary
d["key3"] = "Value3"
d
# Out:
# {'Write': 'Likhna', 'Read': 344213, 'key3': 'Value3'}

# %%
data = {101: "Python", 102 : 'Machine Learning', 103 : "Data Analysis"}
print(data)

# type of the data
print(type(data))
# Out:
# {101: 'Python', 102: 'Machine Learning', 103: 'Data Analysis'}
# <class 'dict'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# indexing 
data[101]
# Out:
# 'Python'

# %%
data[102]
# Out:
# 'Machine Learning'

# %%
# a dictionary  is  mutable. Its means we can change or modify.

print("Before : ",data)

data[102] = 'ML'   # updating 

print("After : ", data)
# Out:
# Before :  {101: 'Python', 102: 'Machine Learning', 103: 'Data Analysis'}
# After :  {101: 'Python', 102: 'ML', 103: 'Data Analysis'}

# %%
# we can also a new element in the dictionary
data[104] = 'Data Science'
data
# Out:
# {101: 'Python', 102: 'ML', 103: 'Data Analysis', 104: 'Data Science'}

# %% [markdown]
# ### Methods and Functions of the Dictionary
# ---
# There are some methods and functions of the dictionary:
# - `keys()` displays a list of keys of the dictionary
# - `values()` all the values of the dictionary
# - `get()`  it is used to get a specific item from the dictionary
# - `items()`  list of tuple pairs of key-value
# - `update()` merge two dictionaries into the first one
# - `del dict[key1]` deletes the key-value pair corresponding key
# - `clear()` delete all the items
# To get more about the methods and functions of the dictionary, we can use `help(dict)` or `dir(dict)`

# %% [markdown]
# Below are some of the methods and functions available for dictionaries in Python. You can execute the cells to see the output of each method and function:
#
# 1. **`keys()`**: Displays a list of keys of the dictionary.
# ```python
# # Execute this cell to see the keys of the sample_dict
# sample_dict = {'a': 1, 'b': 2, 'c': 3}
# sample_dict.keys()

# %%
sample_dict = {'a': 1, 'b': 2, 'c': 3}
sample_dict
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# methods--> key()
sample_dict.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# values()
sample_dict.values()
# Out:
# dict_values([1, 2, 3])

# %%
sample_dict.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
# remove()
sample_dict.clear()

# %%
sample_dict
# Out:
# {}

# %%
# keys()
data.keys()
# Out:
# dict_keys([101, 102, 103, 104])

# %%
# values()
data.values()
# Out:
# dict_values(['Python', 'ML', 'Data Analysis', 'Data Science'])

# %%
# items()
data.items()
# Out:
# dict_items([(101, 'Python'), (102, 'ML'), (103, 'Data Analysis'), (104, 'Data Science')])

# %%
# get()
data.get(103)  # same as data[103]
# Out:
# 'Data Analysis'

# %%
data.get(100)  # get the key is not in the dictionary  it will return nothing, whereas data[100] show key error

# %%
data[101]
# Out:
# 'Python'

# %% [markdown]
# ---
# # Operators and Type of operators <a class="anchor" id="op"></a>
#
# In Python, we have tools called **operators** to work with **data (operand)**. Let's check out the types of operators Python has:
#
# ---

# %%
10 /3
# Out:
# 3.3333333333333335

# %%
10 % 3
# Out:
# 1

# %%
10 // 3
# Out:
# 3

# %%
10 **2
# Out:
# 100

# %%
# assignment operators
x = 5
x
# Out:
# 5

# %%
x += 2 # x = x + 2
x
# Out:
# 7

# %%
x -=4 # x = x -4
x
# Out:
# 3

# %%
x **= 4
x
# Out:
# 81

# %%
x = 6
y = 5

# %%
x == y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
x != y
# Out:
# True

# %%
# logical operator
age = 31
salary = 15

# %%
# coditn A
age < 30, salary < 15
# Out:
# (False, False)

# %%
age < 30 and salary < 15
# Out:
# False

# %%
age < 30, salary > 14
# Out:
# (False, True)

# %%
age < 30 and salary > 14
# Out:
# False

# %%
age < 30 or salary > 14
# Out:
# True

# %%
age > 30, salary < 14
# Out:
# (True, False)

# %%
age < 30 and salary > 14
# Out:
# False

# %%
age > 30, salary > 14
# Out:
# (True, True)

# %%
age > 30 and salary > 14
# Out:
# True

# %%
not(3 < 4)
# Out:
# False

# %%
not(3 >4)
# Out:
# True

# %% [markdown]
# #### 1. Arithmetic Operators
# | Operator | Description    | Example |
# |:--------:|:--------------:|:-------:|
# | `+`      | Addition       | `x + y` |
# | `-`      | Subtraction    | `x - y` |
# | `*`      | Multiplication | `x * y` |
# | `/`      | Division       | `x / y` |
# | `%`      | Modulus        | `x % y` |
# | `**`     | Exponentiation | `x ** y`|
# | `//`     | Floor Division | `x // y`|
#
# #### 2. Assignment Operators
# | Operator | Description                                  | Example |
# |:--------:|:--------------------------------------------:|:-------:|
# | `=`      | Assigns value from right to left             | `x = y` |
# | `+=`     | Adds right operand to left operand           | `x += y`|
# | `-=`     | Subtracts right operand from left operand    | `x -= y`|
# | `*=`     | Multiplies right operand with left operand   | `x *= y`|
# | `/=`     | Divides left operand by right operand        | `x /= y`|
# | `%=`     | Takes modulus using left and right operands  | `x %= y`|
# | `**=`    | Performs exponential calculation on operands | `x **= y`|
# | `//=`    | Performs floor division on operands          | `x //= y`|
#
# #### 3. Relational Operators
# | Operator | Description                               | Example |
# |:--------:|:-----------------------------------------:|:-------:|
# | `==`     | If the values of two operands are equal   | `x == y`|
# | `!=`     | If values of two operands are not equal   | `x != y`|
# | `>`      | If the value of left operand is greater   | `x > y` |
# | `<`      | If the value of left operand is less      | `x < y` |
# | `>=`     | If the value of left operand is greater or equal | `x >= y`|
# | `<=`     | If the value of left operand is less or equal | `x <= y`|
#
# #### 4. Logical Operators
# | Operator | Description   | Example |
# |:--------:|:-------------:|:-------:|
# | `and`    | Logical AND   | `x and y`|
# | `or`     | Logical OR    | `x or y` |
# | `not`    | Logical NOT   | `not x`  |
#
# #### 5. Membership Operators
# | Operator | Description                                      | Example   |
# |:--------:|:------------------------------------------------:|:---------:|
# | `in`     | Evaluates to true if it finds a variable         | `x in y`  |
# | `not in` | Evaluates to true if it does not find a variable | `x not in y`|

# %%
Class = ["Afzal", "Govind","Megha","Pabolu"]
Class
# Out:
# ['Afzal', 'Govind', 'Megha', 'Pabolu']

# %%
"Afzal" in Class
# Out:
# True

# %%
"Rohit" in Class
# Out:
# False

# %%
for student in Class:
    print(student)
# Out:
# Afzal
# Govind
# Megha
# Pabolu

# %%
"S"  not in "suhel"
# Out:
# True

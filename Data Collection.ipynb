# %%
import pandas as pd
import numpy as np
df=pd.read_json(r"C:\Users\Mir Abdul Malique\Downloads\HV_Python\Phone_Comparison_Data_500_rows_updated.json",lines=True)

# %%
df
# Out:
#     Product_ID        Product_Name    Brand   Feature_1       Feature_2  \
# 0        P0001           iPhone 15  OnePlus  4G Support  AMOLED Display
# 1        P0002      Google Pixel 6  Samsung  4G Support  AMOLED Display
# 2        P0003      Google Pixel 6    Apple  4G Support    Fluid AMOLED
# 3        P0004     Google Pixel 5a   Google  5G Support    OLED Display
# 4        P0005        OnePlus Nord    Apple  5G Support  AMOLED Display
# ..         ...                 ...      ...         ...             ...
# 500      P0501           iPhone 16    Apple  5G Support    OLED Display
# 501      P0502  Samsung Galaxy S22  Samsung  5G Support  AMOLED Display
# 502      P0503          OnePlus 10  OnePlus  5G Support    Fluid AMOLED
# 503      P0504      Google Pixel 7   Google  5G Support    OLED Display
# 504      P0505       Realme GT Neo   Realme  5G Support  AMOLED Display
#
#                    Chip  RAM_GB  Storage_GB  Battery_mAh  Camera_Megapixels  \
# ...

# %%
df1=pd.read_excel(r"C:\Users\Mir Abdul Malique\Downloads\HV_Python\iPhone_16_Market_Analysis_1000_Rows.xlsx")
df1
# Out:
#           Date Competitor_Brand Competitor_Model   Price  iPhone_16_Price  \
# 0   2024-04-12             Vivo         GT Neo 6  106820            96265
# 1   2024-01-22           Realme          V27 Pro   55658           108942
# 2   2024-09-30             Vivo       Galaxy S23  103969           133001
# 3   2024-02-23          OnePlus          V27 Pro   70757            99692
# 4   2024-02-22          OnePlus       Galaxy S23  116779           129099
# ..         ...              ...              ...     ...              ...
# 995 2024-10-11             Vivo          Pixel 8  104332           135380
# 996 2024-06-09             Oppo       Galaxy S23   41399           128829
# 997 2024-10-30           Xiaomi       Galaxy S23   56622           135201
# 998 2024-12-30             Oppo          Pixel 8   95671           105773
# 999 2024-05-07             Oppo           Nord 3   48639           135370
#
#      Sales_Volume  iPhone_16_Projected_Sales  Market_Share  \
# ...
